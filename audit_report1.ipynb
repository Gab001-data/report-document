# %%
# import libraries
from docxtpl import DocxTemplate
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.enum.section import WD_SECTION, WD_ORIENTATION
from docx.shared import RGBColor, Mm, Pt, Inches
from docx.oxml import OxmlElement
from docx.oxml.ns import qn
from docx.enum.table import WD_ROW_HEIGHT_RULE
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from urllib.parse import urljoin
import json
from datetime import date, datetime as dt
# Out:
# c:\Users\Gabriel O\Desktop\ACL\ACL\Knowledge Base\Python_Reports\report_temp\Lib\site-packages\docxcompose\properties.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
####################################################################################
# fetch data
####################################################################################

BEARER_TOKEN = 'd358c3e1709f951fe611415e7a0b1956b783127d52d541adc48f649761408f15'
org_id = '11534' #'52734'
id = '492704'
server_url = 'https://apis-us.diligentoneplatform.com'
BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/projects'
headers = {'Authorization' : f'Bearer {BEARER_TOKEN}', 'Content-Type': 'application/vnd.api+json'}
params = {'filter[status]':'active', 'filter[start_date][lte]': dt.today().isoformat(), 'include':'project, project.fieldwork'}

def fetch_data(url, params=None, max_retries=5, timeout=10, backoff_factor=1):
    """
        fetch data from endpoint with maxixum retries, timeout and session management

        Args:
            url(str): targeted endpoint
            max_retries(int): no of retry attempt upon non-response from the server
            timeout(int): prevent prolonged server connection
            backoff_factor = wait multiplier between request
    """
    retries = Retry(total= max_retries, 
                    backoff_factor=backoff_factor, 
                    status_forcelist=[429, 500, 502, 503, 504], #retries on these http errors
                    allowed_methods=['GET'])
    session = requests.session()
    adapter = HTTPAdapter(max_retries=retries)
    session.mount('http://',adapter)
    session.mount('https://', adapter)
    all_data = []
    while url:
        try:
            resp = session.get(url, headers=headers, params=params, timeout=10)
            resp.raise_for_status()
        except Exception as e:
            print(f'failure to fetch data: {e}')
        project_data = resp.json().get('data', [])
        all_data = all_data + project_data if isinstance(project_data, list) else project_data # check and accumulate multiple project or return a single targerted project
        next_page = resp.json()['links']['next'] if isinstance(project_data, list) else None
        url = urljoin(server_url,next_page) if next_page else None
        params = None
    session.close()
    return all_data

# %%
# fetch valid project data ***************************************************************
projects = fetch_data(BASE_URL)

valid_projects = []
for project in projects:
    sd = project.get("attributes", {}).get("start_date", "")
    try:
        if dt.strptime(sd, "%Y-%m-%d").date() <= date.today():
            valid_projects.append(project)
    except ValueError:
            continue

valid_projects, len(valid_projects)
# Out:
# ([{'id': '17702',
#    'type': 'projects',
#    'attributes': {'name': 'Risk_Assessment',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2015-02-17T10:54:17Z',
#     'updated_at': '2022-05-19T12:37:45Z',
#     'description': 'sdsg',
#     'background': None,
#     'budget': 200,
#     'position': 0,
#     'certification': False,
#     'control_performance': True,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2022-05-01',
#     'target_date': '2022-06-08',
#     'custom_attributes': [],
#     'progress': 16.7,
#     'time_spent': 2.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '64148',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/17702/dashboard'}},
#   {'id': '48712',
#    'type': 'projects',
#    'attributes': {'name': 'Productivity SA Demo',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2017-10-08T14:14:10Z',
#     'updated_at': '2022-08-29T09:16:07Z',
#     'description': '',
#     'background': '',
#     'budget': 100,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': '<p>Conclusion noted, and an action plan has been designed.</p>\r\n',
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': 'Behind schedule',
#     'opinion_description': '<p>More work needs to be done to bring all outstanding items up to within expected timelines.</p>\r\n',
#     'purpose': '<table border="0" cellpadding="0" cellspacing="0" style="width:686px;">\r\n\t<tbody>\r\n\t\t<tr>\r\n\t\t\t<td style="height:35px;width:123px;">Strategic Objective number</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Strategic objective</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td style="height:36px;">1</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Strengthen the Institutional capacity of Productivity SA to deliver on its mandate and be financially sustainable (Outcome 5 &amp; 12)</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td style="height:36px;">2</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Provide support to the Government Programmes aimed at sustainable employment and income growth (Outcome 4 &amp; 5)</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td style="height:22px;">3</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Provide support to companies facing economic distress to retain jobs (Outcome 4 &amp; 5)</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td style="height:34px;">4</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Contribute to employment and income growth through research, information generation and dissemination (Outcome 4, 6, 11 &amp; 12)</td>\r\n\t\t</tr>\r\n\t\t<tr>\r\n\t\t\t<td style="height:34px;">5</td>\r\n\t\t\t<td colspan="3" style="width:563px;">Promote social dialogue and a culture of productivity and competitiveness in the workplace and community life (Outcome 4 &amp; 12)</td>\r\n\t\t</tr>\r\n\t</tbody>\r\n</table>\r\n',
#     'scope': '',
#     'start_date': '2020-08-19',
#     'target_date': '2022-08-31',
#     'custom_attributes': [],
#     'progress': 16.7,
#     'time_spent': 4.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '64148',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/48712/dashboard'}},
#   {'id': '95904',
#    'type': 'projects',
#    'attributes': {'name': 'Eugene Project 1',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2019-11-05T10:23:12Z',
#     'updated_at': '2023-05-12T13:45:01Z',
#     'description': 'Creating a blank project',
#     'background': '<p>This is the background of project 1.</p>\r\n',
#     'budget': 400,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': '<p>This is the purpose of project 1.</p>\r\n',
#     'scope': '<p>This is the scope of project 1.</p>\r\n',
#     'start_date': '2019-11-06',
#     'target_date': '2019-11-15',
#     'custom_attributes': [],
#     'progress': 50.0,
#     'time_spent': 1.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/95904/dashboard'}},
#   {'id': '119436',
#    'type': 'projects',
#    'attributes': {'name': 'Workplan',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-07-28T14:18:02Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-07-28',
#     'target_date': '2020-07-28',
#     'custom_attributes': [],
#     'progress': 11.1,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '64148',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/119436/dashboard'}},
#   {'id': '125851',
#    'type': 'projects',
#    'attributes': {'name': 'Audit Project 1 2020 2',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-10-21T09:16:50Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': 200,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-10-21',
#     'target_date': '2020-10-21',
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 16.7,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/125851/dashboard'}},
#   {'id': '127313',
#    'type': 'projects',
#    'attributes': {'name': 'Framework testing',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-11-12T06:36:17Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-11-12',
#     'target_date': '2020-11-12',
#     'custom_attributes': [{'id': '21390',
#       'term': 'Short answer',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '21391',
#       'term': 'Paragraph',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 12.5,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '190374',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/127313/dashboard'}},
#   {'id': '127386',
#    'type': 'projects',
#    'attributes': {'name': 'User access testing',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-11-13T07:20:55Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-11-13',
#     'target_date': '2020-11-13',
#     'custom_attributes': [{'id': '38407',
#       'term': 'Executive Summary ',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 8.3,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '186443',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/127386/dashboard'}},
#   {'id': '128178',
#    'type': 'projects',
#    'attributes': {'name': 'Backward Framework linking',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-11-25T08:55:12Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'I want to see if I create a risk and control in a project and push it to a framework will it create a link. It does not',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-11-25',
#     'target_date': '2020-11-25',
#     'custom_attributes': [{'id': '38407',
#       'term': 'Executive Summary ',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 12.5,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '186443',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/128178/dashboard'}},
#   {'id': '128254',
#    'type': 'projects',
#    'attributes': {'name': 'Certificate and control performance rolledforward',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-11-26T13:39:59Z',
#     'updated_at': '2023-12-12T13:30:41Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': True,
#     'control_performance': True,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-11-26',
#     'target_date': '2020-11-26',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 8.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/128254/dashboard'}},
#   {'id': '128944',
#    'type': 'projects',
#    'attributes': {'name': 'SM IT General Controls Review (SOX Context) V2',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-12-07T16:09:13Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-12-07',
#     'target_date': '2020-12-07',
#     'custom_attributes': [],
#     'progress': 1.2,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63469',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/128944/dashboard'}},
#   {'id': '129172',
#    'type': 'projects',
#    'attributes': {'name': 'risk rating scale',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2020-12-10T14:28:36Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2020-12-10',
#     'target_date': '2020-12-10',
#     'custom_attributes': [],
#     'progress': 12.5,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '191880',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/129172/dashboard'}},
#   {'id': '131344',
#    'type': 'projects',
#    'attributes': {'name': 'Audit Project 1 2020',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-01-07T06:38:04Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': '<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;">Highbond Success Plan</p>\r\n\r\n<p style="text-align:center;">Program Guide and Course Outline</p>\r\n\r\n<p style="text-align:center;">[08-Sep-2020]</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><u>Highbond Success Plan</u></strong></p>\r\n\r\n<p style="text-align:center;"><strong><u>Program Guide</u></strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Introduction</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><em>SurTech strives to make our customers successful as effectively and efficiently as possible. Therefore, this program is designed to provide you with the necessary skills and knowledge to competently begin using the Highbond software as soon as the engagement is complete. We use a practical, real-world approach that allows you to incorporate your existing audit workflow, while becoming proficient in using our gear. </em></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Program Objective</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>At the end of the five-day enablement, you will be able to use Highbond to effectively manage your audit/assessments.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Prerequisites</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>The following tasks should be completed prior to attending the in-person sessions.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<ul>\r\n\t<li>Complete <em>Managing your audit with AuditBond program (GRC 101 V5) </em>on Academy</li>\r\n\t<li>Provide Administration access to Highbond through Launchpad</li>\r\n</ul>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Required Resources</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>To maximize the value gained from these sessions, attendees are encouraged to provide the following documents prior to the training.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><span style="color:#1f497d;">Set-Up &amp;\xa0Planning\xa0for Audit</span></strong></p>\r\n\r\n<ul>\r\n\t<li>General</li>\r\n</ul>\r\n\r\n<ul style="list-style-type:circle;">\r\n\t<li>Audit\xa0Risk\xa0Assessments\xa0completed/ Risk Management Strategy/ Policy (rating of risks)</li>\r\n\t<li>Audit Charter</li>\r\n\t<li>IA Methodology\xa0(Includes the\xa0assessment methods and rating method ...
#     'budget': 200,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': '',
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': '',
#     'opinion_description': '<p><a data-dynamic-hyperlink="risks" href="https://cts.projects.highbond.com/audits/131344/objectives/649042/risks/3930845" target="">https://cts.projects.highbond.com/audits/131344/objectives/649042/risks/3930845</a></p>\r\n',
#     'purpose': '<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;">Highbond Success Plan</p>\r\n\r\n<p style="text-align:center;">Program Guide and Course Outline</p>\r\n\r\n<p style="text-align:center;">[08-Sep-2020]</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><u>Highbond Success Plan</u></strong></p>\r\n\r\n<p style="text-align:center;"><strong><u>Program Guide</u></strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Introduction</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><em>SurTech strives to make our customers successful as effectively and efficiently as possible. Therefore, this program is designed to provide you with the necessary skills and knowledge to competently begin using the Highbond software as soon as the engagement is complete. We use a practical, real-world approach that allows you to incorporate your existing audit workflow, while becoming proficient in using our gear. </em></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Program Objective</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>At the end of the five-day enablement, you will be able to use Highbond to effectively manage your audit/assessments.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Prerequisites</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>The following tasks should be completed prior to attending the in-person sessions.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<ul>\r\n\t<li>Complete <em>Managing your audit with AuditBond program (GRC 101 V5) </em>on Academy</li>\r\n\t<li>Provide Administration access to Highbond through Launchpad</li>\r\n</ul>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Required Resources</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>To maximize the value gained from these sessions, attendees are encouraged to provide the following documents prior to the training.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><span style="color:#1f497d;">Set-Up &amp;\xa0Planning\xa0for Audit</span></strong></p>\r\n\r\n<ul>\r\n\t<li>General</li>\r\n</ul>\r\n\r\n<ul style="list-style-type:circle;">\r\n\t<li>Audit\xa0Risk\xa0Assessments\xa0completed/ Risk Management Strategy/ Policy (rating of risks)</li>\r\n\t<li>Audit Charter</li>\r\n\t<li>IA Methodology\xa0(Includes the\xa0assessment methods and rating methodolo ...
#     'scope': '<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;">Highbond Success Plan</p>\r\n\r\n<p style="text-align:center;">Program Guide and Course Outline</p>\r\n\r\n<p style="text-align:center;">[08-Sep-2020]</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p style="text-align:center;">\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><u>Highbond Success Plan</u></strong></p>\r\n\r\n<p style="text-align:center;"><strong><u>Program Guide</u></strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Introduction</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><em>SurTech strives to make our customers successful as effectively and efficiently as possible. Therefore, this program is designed to provide you with the necessary skills and knowledge to competently begin using the Highbond software as soon as the engagement is complete. We use a practical, real-world approach that allows you to incorporate your existing audit workflow, while becoming proficient in using our gear. </em></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Program Objective</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>At the end of the five-day enablement, you will be able to use Highbond to effectively manage your audit/assessments.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Prerequisites</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>The following tasks should be completed prior to attending the in-person sessions.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<ul>\r\n\t<li>Complete <em>Managing your audit with AuditBond program (GRC 101 V5) </em>on Academy</li>\r\n\t<li>Provide Administration access to Highbond through Launchpad</li>\r\n</ul>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><strong>Required Resources</strong></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p>To maximize the value gained from these sessions, attendees are encouraged to provide the following documents prior to the training.</p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p style="text-align:center;"><strong><span style="color:#1f497d;">Set-Up &amp;\xa0Planning\xa0for Audit</span></strong></p>\r\n\r\n<ul>\r\n\t<li>General</li>\r\n</ul>\r\n\r\n<ul style="list-style-type:circle;">\r\n\t<li>Audit\xa0Risk\xa0Assessments\xa0completed/ Risk Management Strategy/ Policy (rating of risks)</li>\r\n\t<li>Audit Charter</li>\r\n\t<li>IA Methodology\xa0(Includes the\xa0assessment methods and rating methodologi ...
#     'start_date': '2021-01-07',
#     'target_date': '2021-01-07',
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 25.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/131344/dashboard'}},
#   {'id': '138083',
#    'type': 'projects',
#    'attributes': {'name': 'Secret Test',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-11T16:24:49Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'ABSA Secret Test',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-11',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138083/dashboard'}},
#   {'id': '138609',
#    'type': 'projects',
#    'attributes': {'name': 'Sarbanes-Oxley (SOX) Audit Template (COSO 2013 Framework) V2',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:24:26Z',
#     'updated_at': '2025-06-02T12:05:08Z',
#     'description': '',
#     'background': '<p>Testing Background</p>',
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': '<p>Testing Purpose</p>',
#     'scope': '<p>Testing Scope</p>',
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 4.2,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63469',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138609/dashboard'}},
#   {'id': '138610',
#    'type': 'projects',
#    'attributes': {'name': 'IT General Controls Review (SOX Context) V2',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:24:35Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
#     'background': None,
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63469',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138610/dashboard'}},
#   {'id': '138611',
#    'type': 'projects',
#    'attributes': {'name': 'Sales Commissions Audit',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:24:43Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an audit program for an internal and external sales rep review.',
#     'background': None,
#     'budget': 120,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138611/dashboard'}},
#   {'id': '138612',
#    'type': 'projects',
#    'attributes': {'name': 'IT General Controls Review (IA Context)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:24:59Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template for a review of IT General Controls in a SOX or internal audit context.',
#     'background': None,
#     'budget': 400,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 1.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138612/dashboard'}},
#   {'id': '138614',
#    'type': 'projects',
#    'attributes': {'name': 'SOC Audit - Technology Service Organization',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:25:25Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template for a SOC/SAS70/SSAE16 service auditor examination for service organizations in the IT services, software, or related technology industries.',
#     'background': None,
#     'budget': 320,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 1.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63471',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138614/dashboard'}},
#   {'id': '138615',
#    'type': 'projects',
#    'attributes': {'name': 'Travel & Entertainment Audit (Analytics Instructed)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:25:36Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an analytics-enabled audit program of the Travel & Entertainment Cycle.',
#     'background': None,
#     'budget': 120,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138615/dashboard'}},
#   {'id': '138616',
#    'type': 'projects',
#    'attributes': {'name': 'Order to Cash Audit (Analytics Instructed)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:25:43Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an analytics-enabled audit program of the Order to Cash Cycle.',
#     'background': None,
#     'budget': 400,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138616/dashboard'}},
#   {'id': '138617',
#    'type': 'projects',
#    'attributes': {'name': 'Purchase Card Audit (Analytics Instructed)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:25:51Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an analytics-enabled audit program of the Purchase Card (P-Card) Cycle.',
#     'background': None,
#     'budget': 200,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138617/dashboard'}},
#   {'id': '138618',
#    'type': 'projects',
#    'attributes': {'name': 'Purchase Card Audit (Analytics Instructed)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:26:03Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an analytics-enabled audit program of the Purchase Card (P-Card) Cycle.',
#     'background': None,
#     'budget': 200,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138618/dashboard'}},
#   {'id': '138619',
#    'type': 'projects',
#    'attributes': {'name': 'Payroll Audit (Analytics Instructed)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:26:13Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'Project template including an analytics-enabled audit program of the Payroll Cycle.',
#     'background': None,
#     'budget': 400,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138619/dashboard'}},
#   {'id': '138621',
#    'type': 'projects',
#    'attributes': {'name': 'FCPA Compliance Investigation',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:26:39Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': 'This project is intended to provide you with insight on testing FCPA compliance, and should not be construed as legal advice on the part of Galvanize. The FCPA is complex. You are cautioned to obtain independent, qualified legal and accounting advice regarding the FCPA if you have specific FCPA questions or concerns.',
#     'background': '<p>The Foreign Corrupt Practices Act (FCPA) of 1977 is a US Federal Law primarily intended to prohibit payments of bribes to foreign officials and political figures (also know as the Anti-Bribery Provision). The second provision requires that companies maintain transparency requirements for business accounting as outlined by the Securities Exchange Act of 1934 (also know as the Accounting Provision).</p>\r\n<p>The FCPA applies to:</p>\r\n<p>* Both Public &amp; Private US Companies<br>* Non–US Companies</p>\r\n<p>If a non-US company has a US subsidiary, under specific conditions the subsidiary can be subject to the FCPA.</p>',
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 0,
#     'number_of_testing_rounds': 0,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': '<p>This project is intended to provide you with insight on testing FCPA compliance, and should not be construed as legal advice on the part of ACL. The FCPA is complex. You are cautioned to obtain independent, qualified legal and accounting advice regarding the FCPA if you have specific FCPA questions or concerns.</p>',
#     'scope': '<p>We will perform control and substantive testing to highlight any control weaknesses and flag potential violations related to the FCPA and other anti-corruption regulations.</p>\r\n<p><br>We will include all key business processes and a general governance review within the project scope, specifically:\xa0</p>\r\n<ul>\r\n<li>Governance &amp; Monitoring</li>\r\n<li>Business Partners and M&amp;A</li>\r\n<li>Third Party Management</li>\r\n<li>Sales Practices</li>\r\n<li>Chart of Accounts</li>\r\n<li>Disbursements and Credit Memos</li>\r\n<li>Payroll</li>\r\n<li>Travel and Entertainment</li>\r\n<li>Petty Cash</li>\r\n</ul>\r\n<p>\xa0</p>',
#     'start_date': '2021-02-18',
#     'target_date': '2021-02-18',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '63475',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/138621/dashboard'}},
#   {'id': '138622',
#    'type': 'projects',
#    'attributes': {'name': 'GAGAS Performance Audit (GAO 2018)',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2021-02-18T06:26:51Z',
#     'updated_at': '2021-08-04T12:00:29Z',
#     'description': '',
# ...
#     'budget': 3000,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 2,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': '<p><span style="color:#0000ff;"><em><u>Note</u>: The following is for informational purposes only. It is intended to provide guidance on\xa0GAGAS requirements for the specific topic.\xa0Examples are provided after the U.S. GAO citation.</em></span></p>\r\n\r\n<p><strong>Generally Accepted Government Auditing Standards (GAGAS) for Financial Audits</strong></p>\r\n\r\n<ul>\r\n\t<li>\n<strong>Financial Audits\xa0</strong>- (1.17) Financial audits provide independent assessments of whether entities’ reported financial information (e.g., financial condition, results, and use of resources) is presented fairly, in all material respects, in accordance with recognized criteria. Financial audits conducted in accordance with GAGAS include financial statement audits and other related financial audits. (a)\xa0Financial statement audits: The primary purpose of a financial statement audit is to provide financial statement users with an opinion by an auditor on whether an entity’s financial statements are presented fairly, in all material respects, in accordance with an applicable financial reporting framework. Reporting on financial statement audits conducted in accordance with GAGAS also includes reports on internal control over financial reporting and on compliance with provisions of laws, regulations, contracts, and grant agreements that have a material effect on the financial statements. (b) Other types of financial audits: Other types of financial audits conducted in accordance with GAGAS entail various scopes of work, including:\xa0(1) obtaining sufficient, appropriate evidence to form an opinion on a single financial statement or specified elements, accounts, or line items of a financial statement;\xa0(2) issuing letters (commonly referred to as comfort letters) for underwriters and certain other requesting parties;\xa0(3) auditing applicable compliance and internal control requirements relating to one or more government programs;\xa0and (4) conducting an audit of internal control over financial reporting that is integrated with an audit of financial statements (integrated audit).</li>\r\n</ul>\r\n\r\n<p>U.S. Government Accountability Office (GAO): 2018\xa0GAO-18-568G\xa0Government Auditing Standards\xa0</p>\r\n\r\n<p>==========================================================================================</p>\r\n\r\n<p><span style="color:#0000ff;"><strong>Example Audit Objectives\xa0from the September 2016\xa0Financial Audit of the U.S. Government\'s Consolidated Financial Statements</strong></span></p>\r\n\r\n<p><span style="color:#0000ff;">Our objectives were to audit the consolidated financial statements consisting of the (1) accrual based consolidated financial statements as of and for the fiscal years ended September 30, 2016, and 2015, and (2) sustainability financial statements, which consist of the 2016 and 2015 Statements of Long-Term Fiscal Projections; the 2016, 2015, 2014, 2013, and 2012 Statements of Social Insurance; and the 2016 and 2015 Statements of Changes in Social Insurance Amounts. Our objectives also included reporting on internal control over financial reporting and on compliance with selected provisions of applicable laws, regulations, contracts, and grant agreements. The Chief Financial Officers Act of 1990 (CFO Act), as expanded by the Government Management Reform Act of 1994 (GMRA), requires the inspectors general of the 24 CFO Act agencies to be responsible for annual audits of agency-wide financial statements prepared by these agencies.\xa0GMRA requires GAO to be responsible for the audit of the U.S. government’s consolidated financial statements,\xa0and the Accountability of Tax Dollars Act of 2002 (ATDA) requires most other executive branch entities to annually prepare financial statements and have them audited.\xa0The Office of Management and Budget (OMB) and the Department of the Treasury (Treasury) have identified 39 federal entities that are significant to the U.S. government’s fisc ...
#     'scope': '<p><span style="color:#0000ff;"><em><u>Note</u>: The following is for informational purposes only. It is intended to provide guidance on\xa0GAGAS requirements for the specific topic.\xa0Examples are provided after the U.S. GAO citation.</em></span></p>\r\n\r\n<p><strong>Generally Accepted Government Auditing Standards (GAGAS) for Financial Audits</strong></p>\r\n\r\n<ul>\r\n\t<li>\n<strong>Financial Statement Audits</strong>\xa0- (1.17)(a)\xa0The primary purpose of a financial statement audit is to provide financial statement users with an opinion by an auditor on whether an entity’s financial statements are presented fairly, in all material respects, in accordance with an applicable financial reporting framework. Reporting on financial statement audits conducted in accordance with GAGAS also includes reports on internal control over financial reporting and on compliance with provisions of laws, regulations, contracts, and grant agreements that have a material effect on the financial statements. b. Other types of financial audits: Other types of financial audits conducted in accordance with GAGAS entail various scopes of work, including</li>\r\n\t<li>\n<strong>Other Types of Financial Audits</strong>\xa0- (1.17)(b)\xa0Other types of financial audits conducted in accordance with GAGAS entail various scopes of work, including (1) obtaining sufficient, appropriate evidence to form an opinion on a single financial statement or specified elements, accounts, or line items of a financial statement;\xa0(2) issuing letters (commonly referred to as comfort letters) for underwriters and certain other requesting parties;\xa0(3) auditing applicable compliance and internal control requirements relating to one or more government programs;\xa0and (4) conducting an audit of internal control over financial reporting that is integrated with an audit of financial statements (integrated audit).</li>\r\n</ul>\r\n\r\n<p>U.S. Government Accountability Office (GAO): 2018\xa0GAO-18-568G\xa0Government Auditing Standards\xa0</p>\r\n\r\n<p>==========================================================================================</p>\r\n\r\n<p><span style="color:#0000ff;"><strong>Example Audit Scope from the September 2016\xa0Financial Audit of the U.S. Government\'s Consolidated Financial Statements:</strong></span></p>\r\n\r\n<p><span style="color:#0000ff;">Our audit approach regarding the accrual-based consolidated financial statements primarily focused on determining the current status of the material weaknesses that contributed to our disclaimer of opinion on the accrual-based consolidated financial statements and the other material weaknesses affecting internal control that we reported in our report on the consolidated financial statements for fiscal year 2015.\xa0We also separately audited the financial statements of certain component entities, and parts of a significant component entity, including the following.\xa0</span></p>\r\n\r\n<ul>\r\n\t<li><span style="color:#0000ff;">We audited and expressed an unmodified opinion on the Internal Revenue Service’s (IRS) financial statements as of and for the fiscal years ended September 30, 2016, and 2015.In fiscal years 2016 and 2015, IRS collected about $3.3 trillion in tax payments each year and paid about $426 billion and $403 billion, respectively, in refunds to taxpayers. For fiscal year 2016, we continued to report a material weakness in internal control over unpaid assessments that resulted in ineffective internal control over financial reporting. In addition, we continued to report a significant deficiency in IRS’s internal control over financial reporting systems. We also reported that we found no reportable noncompliance for fiscal year 2016 with provisions of applicable laws, regulations, contracts, and grant agreements we tested.\xa0</span></li>\r\n\t<li><span style="color:#0000ff;">We audited and expressed an unmodified opinion on the Schedules of Federal Debt managed by Treasury ...
#     'start_date': '2025-08-13',
#     'target_date': '2025-08-13',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '304295',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/488797/dashboard'}},
#   {'id': '490182',
#    'type': 'projects',
#    'attributes': {'name': 'ITGC - Financial Audit',
#     'state': 'active',
#     'status': 'proposed',
#     'created_at': '2025-08-19T07:41:38Z',
#     'updated_at': '2025-08-19T07:41:38Z',
#     'description': 'Attempting to use PCAOB AS 2201 together with COSO 2013 to provide for the status of effectiveness of operating controls',
#     'background': None,
#     'budget': 160,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': False,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 2,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2025-01-01',
#     'target_date': '2025-03-31',
#     'custom_attributes': [],
#     'progress': 0.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '297541',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/490182/dashboard'}},
#   {'id': '490611',
#    'type': 'projects',
#    'attributes': {'name': 'Test Project',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2025-08-20T11:34:43Z',
#     'updated_at': '2025-08-20T11:34:43Z',
#     'description': 'Test Project',
#     'background': None,
#     'budget': 16,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': None,
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': None,
#     'opinion_description': None,
#     'purpose': None,
#     'scope': None,
#     'start_date': '2025-08-20',
#     'target_date': '2025-08-22',
#     'custom_attributes': [{'id': '151043',
#       'term': 'Scope',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '152124',
#       'term': 'Department',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '152132',
#       'term': 'Report Date',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'progress': 20.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '419957',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/490611/dashboard'}},
#   {'id': '492704',
#    'type': 'projects',
#    'attributes': {'name': 'SURTECH TEST -Gabe testing',
#     'state': 'active',
#     'status': 'active',
#     'created_at': '2025-08-26T09:26:02Z',
#     'updated_at': '2025-08-26T12:37:16Z',
#     'description': '',
#     'background': '<p>As part of the Surtech independent review process, Internal Audit and Risk Function conducted a Test Audit. This is included in the Approved 2023/2024 Annual Internal Audit Plan.</p><p>Internal Audit and Risk Function’s work predominantly uses the risk-based approach. That is, the team obtains an understanding of the work that the auditable section does, areas that expose the Company to risks are identified and then audit responses are developed to test if the controls put in place are operating effectively in mitigating the identified risks.\xa0</p>',
#     'budget': None,
#     'position': 0,
#     'certification': False,
#     'control_performance': False,
#     'risk_assurance': True,
#     'management_response': '',
#     'max_sample_size': 25,
#     'number_of_testing_rounds': 1,
#     'opinion': 'Improvement Required',
#     'opinion_description': '<p>Surtech‘s Preventive Maintenance System for it’s assets is still in the early stages if we are to use a Capability maturity model. Processes to improve the maintenance system are on-going as seen in the recent development of some job cards. As a result, there are some improvement areas that have been highlighted that need a coordinated cross functional effort to ensure an effective maintenance program is implemented at the Company. \xa0</p>',
#     'purpose': '<p>The objective of this engagement was to provide assurance over the operating effectiveness of controls put in place to maintain critical services and to ensure integrity of operations at Surtech HQ and Satellite offices.\xa0</p>',
#     'scope': '<p><span style=\'background-color:rgb(255,255,255);color:rgb(0,0,0);font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:11pt;\'><span class="TextRun SCXW155999413 BCX8 NormalTextRun SpellingErrorV2Themed DefaultHighlightTransition" style="border-bottom:1px solid transparent;font-style:normal;font-weight:400;letter-spacing:normal;line-height:19.425px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">Surtech</span><span class="TextRun SCXW155999413 BCX8 NormalTextRun" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:19.425px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">, as an organisation that ……………………</span><span class="EOP SCXW155999413 BCX8" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:19.425px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">\xa0</span></span></p>',
#     'start_date': '2025-08-26',
#     'target_date': '2025-08-26',
#     'custom_attributes': [{'id': '151043',
#       'term': 'Scope',
#       'value': ['<p>In general, this Engagement involved testing the appropriateness of the design and operating effectiveness of controls designed to mitigate the risks identified during the planning phase as shown in 6 below. &nbsp;&nbsp;</p>'],
#       'required': False,
#       'default_values': []},
#      {'id': '152124',
#       'term': 'Department',
#       'value': ['Operations Department'],
#       'required': False,
#       'default_values': []},
#      {'id': '152132',
#       'term': 'Report Date',
#       'value': ['2023-10-24'],
#       'required': False,
#       'default_values': []}],
#     'progress': 30.0,
#     'time_spent': 0.0,
#     'planned_start_date': None,
#     'planned_end_date': None,
#     'planned_milestone_date': None,
#     'actual_start_date': None,
#     'actual_end_date': None,
#     'actual_milestone_date': None,
#     'tag_list': []},
#    'relationships': {'project_type': {'data': {'id': '419957',
#       'type': 'project_types'}}},
#    'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/dashboard'}}],
#  313)

# %%
# fetch planning files data for specied project ***************************************************************
project_plannings = {}
working_project = [project for project in valid_projects if project['id']==id] # filter for project of interest.
for project in working_project:
    project_id = project['id']
    BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/projects/{project_id}/planning_files'
    plannings = fetch_data(BASE_URL, params=None)
    project_plannings[project_id] = plannings
project_plannings, len(project_plannings)
# Out:
# ({'492704': []}, 1)

# %%
# fetch result files data **************************************************************
project_results = {}
for project in working_project:
    project_id = project['id']
    BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/projects/{project_id}/results_files'
    results = fetch_data(BASE_URL, params=None)
    project_results[project_id] = results
project_results, len(project_results)
# Out:
# ({'492704': []}, 1)

# %%
# fetch objective data **************************************************************
project_objectives = {}
for project in working_project:
    project_id = project['id']
    BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/projects/{project_id}/objectives'
    objectives = fetch_data(BASE_URL, params=None)
    project_objectives[project_id] = objectives
project_objectives, len(project_objectives)
# Out:
# ({'492704': [{'id': '1896423',
#     'type': 'objectives',
#     'attributes': {'title': 'Operations Department',
#      'description': '',
#      'reference': '01',
#      'division_department': '',
#      'owner': '',
#      'executive_owner': '',
#      'position': 1,
#      'custom_attributes': [],
#      'created_at': '2025-08-26T12:57:08Z',
#      'updated_at': '2025-08-26T12:57:08Z',
#      'risk_control_matrix_id': '1895050',
#      'walkthrough_summary_id': '1896238',
#      'test_plan_id': '1884576',
#      'testing_round_1_id': '1260330',
#      'testing_round_2_id': None,
#      'testing_round_3_id': None,
#      'testing_round_4_id': None},
#     'relationships': {'project': {'data': {'id': '492704',
#        'type': 'projects'}},
#      'assigned_user': {'data': {'id': 'SZeo97qjNcBnDniLQnWd',
#        'type': 'users'}},
#      'owner_user': {'data': None},
#      'executive_owner_user': {'data': None}}}]},
#  1)

# %%
# fetch risk data **************************************************************
## data structure: {project_id: objective_id: [risk items]}
project_objectives_risks = {}
for project in working_project:
    project_id = project['id']
    project_objectives_risks[project_id] = {}   # dict to hold object-risk data for each project
    for objective in project_objectives[project_id]:
        objective_id = objective['id']
        if objective_id:
            BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/objectives/{objective_id}/risks'
            risks = fetch_data(BASE_URL, params=None)
            project_objectives_risks[project_id][objective_id] = risks
project_objectives_risks, len(project_objectives_risks)
# Out:
# ({'492704': {'1896423': [{'id': '8232794',
#      'type': 'risks',
#      'attributes': {'title': 'Non-adherence to approved Preventive Maintenance Plan',
#       'description': '<p>Non-adherence to approved Preventive Maintenance Plan (PMP) of critical assets that might compromise the safety of the operations\xa0\xa0</p>',
#       'risk_id': 'R1',
#       'position': 1,
#       'impact': 'Major',
#       'likelihood': 'Likely',
#       'owner': '',
#       'custom_attributes': [{'id': '151076',
#         'term': 'Site',
#         'value': [],
#         'required': False,
#         'default_values': []}],
#       'custom_factors': [],
#       'created_at': '2025-08-26T13:18:09Z',
#       'updated_at': '2025-08-26T13:18:09Z'},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}}},
#     {'id': '8232795',
#      'type': 'risks',
#      'attributes': {'title': 'Incompleteness of the PMP may result in rejected claims',
#       'description': '<p>Incompleteness of the PMP may result in rejected claims by the Insurance company in case of breakdowns.\xa0</p>',
#       'risk_id': 'R2',
#       'position': 2,
#       'impact': 'Major',
#       'likelihood': 'Likely',
#       'owner': '',
#       'custom_attributes': [{'id': '151076',
#         'term': 'Site',
#         'value': [],
#         'required': False,
#         'default_values': []}],
#       'custom_factors': [],
#       'created_at': '2025-08-26T13:18:10Z',
#       'updated_at': '2025-08-26T13:18:10Z'},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}}},
#     {'id': '8232796',
#      'type': 'risks',
#      'attributes': {'title': 'Lack of inhouse technical expertise ',
#       'description': '<p>Lack of inhouse technical expertise on some critical asset for example Impact Report Mapping system\xa0</p>',
#       'risk_id': 'R3',
#       'position': 3,
#       'impact': 'Major',
#       'likelihood': 'Likely',
#       'owner': '',
#       'custom_attributes': [{'id': '151076',
#         'term': 'Site',
#         'value': [],
#         'required': False,
#         'default_values': []}],
#       'custom_factors': [],
#       'created_at': '2025-08-26T13:18:11Z',
#       'updated_at': '2025-08-26T13:18:11Z'},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}}},
#     {'id': '8232797',
#      'type': 'risks',
#      'attributes': {'title': 'Delays in purchase and delivery of maintenance related services',
#       'description': '<p>Delays in purchase and delivery of maintenance related services, spares and equipment which results in loss of time and money, and compromise safety and security (in case of CCTV) of operations \xa0</p>',
#       'risk_id': 'R4',
#       'position': 4,
#       'impact': 'Catastrophic',
#       'likelihood': 'Likely',
#       'owner': '',
#       'custom_attributes': [{'id': '151076',
#         'term': 'Site',
#         'value': [],
#         'required': False,
#         'default_values': []}],
#       'custom_factors': [],
#       'created_at': '2025-08-26T13:18:11Z',
#       'updated_at': '2025-08-26T13:18:11Z'},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}}}]}},
#  1)

# %%
# fetch control data **************************************************************
## data structure: {project_id: objective_id: [controls]}
project_objectives_controls = {}
for project in working_project:
    project_id =  project['id'] 
    project_objectives_controls[project_id] = {}   # dict to hold object-risk data for each project
    for objective in project_objectives[project_id]:
        objective_id = objective['id']
        if objective_id:
            BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/objectives/{objective_id}/controls'
            controls = fetch_data(BASE_URL, params=None)
            project_objectives_controls[project_id][objective_id] = controls
project_objectives_controls, len(project_objectives_controls)
# Out:
# ({'492704': {'1896423': [{'id': '14421648',
#      'type': 'controls',
#      'attributes': {'title': 'Training and experience of support',
#       'description': '<p>Training and experience of support is pivotal for the asstst that don’t have manuals or reference documents to an extent that when referenced, there was not significant deviation in some cases\xa0</p>',
#       'control_id': '01',
#       'owner': '',
#       'position': 1,
#       'created_at': '2025-08-26T13:18:09Z',
#       'updated_at': '2025-08-26T13:18:09Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421648'}},
#     {'id': '14421649',
#      'type': 'controls',
#      'attributes': {'title': 'Random inconsistent scheduled visits',
#       'description': '<p>Random inconsistent scheduled visits to these sites for preventive maintenance and condition monitoring</p>',
#       'control_id': '06',
#       'owner': '',
#       'position': 6,
#       'created_at': '2025-08-26T13:18:10Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421649'}},
#     {'id': '14421650',
#      'type': 'controls',
#      'attributes': {'title': 'Contractual Agreement ',
#       'description': '<p>Contractual Agreement\xa0</p>',
#       'control_id': '07',
#       'owner': '',
#       'position': 7,
#       'created_at': '2025-08-26T13:18:10Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421650'}},
#     {'id': '14421651',
#      'type': 'controls',
#      'attributes': {'title': 'Condition monitoring checklists',
#       'description': '<p>All sites have condition monitoring checklists for some of the equipment\xa0</p>',
#       'control_id': '02',
#       'owner': '',
#       'position': 2,
#       'created_at': '2025-08-26T13:18:11Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421651'}},
#     {'id': '14421652',
#      'type': 'controls',
#      'attributes': {'title': 'External contractors carry out annual preventive maintenance ',
#       'description': '<p>External contractors carry out annual preventive maintenance on some of the equipment like firefighting equipment,\xa0</p>',
#       'control_id': '03',
#       'owner': '',
#       'position': 3,
#       'created_at': '2025-08-26T13:18:11Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421652'}},
#     {'id': '14421653',
#      'type': 'controls',
#      'attributes': {'title': 'Review of job cards by  Manager/ Supervisor ',
#       'description': '<p>Review of job cards by \xa0Manager/ Supervisor\xa0</p>',
#       'control_id': '04',
#       'owner': '',
#       'position': 4,
#       'created_at': '2025-08-26T13:18:12Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421653'}},
#     {'id': '14421654',
#      'type': 'controls',
#      'attributes': {'title': 'Condition monitoring inspections',
#       'description': '<p>Condition monitoring inspections and checklists\xa0</p>',
#       'control_id': '05',
#       'owner': '',
#       'position': 5,
#       'created_at': '2025-08-26T13:18:12Z',
#       'updated_at': '2025-08-26T13:18:13Z',
#       'custom_attributes': [],
#       'audit_is_workplan': False},
#      'relationships': {'objective': {'data': {'id': '1896423',
#         'type': 'objectives'}}},
#      'links': {'ui': 'https://cts.projects.diligentoneplatform.com/audits/492704/objectives/1896423/controls/14421654'}}]}},
#  1)

# %%
# fetch control test data **************************************************************
## data structure: {project_id: objective_id: control_id: [control_test]}
### a control can have one or more testing data depending on the testing rounds
project_objectives_controls_tests = {}
for project in project_objectives_controls:
    project_id = project
    project_objectives_controls_tests[project_id] = {}   # dict to hold object-risk data for each project
    for objective in project_objectives_controls[project_id]:
        objective_id = objective
        project_objectives_controls_tests[project_id][objective_id]={}
        for control in project_objectives_controls[project_id][objective_id]:
            control_id = control['id']
            params = {'filter[project.id]':project_id, 'filter[control.id]':control_id} # filter for project and specified control
            BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/control_tests'
            control_tests = fetch_data(BASE_URL, params=params)
            project_objectives_controls_tests[project_id][objective_id][control_id] = control_tests
project_objectives_controls_tests, len(project_objectives_controls_tests)
# Out:
# ({'492704': {'1896423': {'14421648': [{'id': '9882762',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Partially Operating Effectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:09Z',
#        'updated_at': '2025-08-26T13:57:34Z'},
#       'relationships': {}}],
#     '14421649': [{'id': '9882763',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Operating Ineffectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:10Z',
#        'updated_at': '2025-08-26T14:29:04Z'},
#       'relationships': {}}],
#     '14421650': [{'id': '9882764',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Partially Operating Effectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:10Z',
#        'updated_at': '2025-08-26T14:31:19Z'},
#       'relationships': {}}],
#     '14421651': [{'id': '9882765',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Operating Ineffectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:11Z',
#        'updated_at': '2025-08-26T14:18:22Z'},
#       'relationships': {}}],
#     '14421652': [{'id': '9882766',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Partially Operating Effectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:11Z',
#        'updated_at': '2025-08-26T14:20:41Z'},
#       'relationships': {}}],
#     '14421653': [{'id': '9882767',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Partially Operating Effectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:12Z',
#        'updated_at': '2025-08-26T14:22:38Z'},
#       'relationships': {}}],
#     '14421654': [{'id': '9882768',
#       'type': 'control_tests',
#       'attributes': {'assignee_name': None,
#        'testing_round_number': 1,
#        'not_applicable': False,
#        'sample_size': None,
#        'testing_results': None,
#        'testing_conclusion': False,
#        'testing_conclusion_status': 'Partially Operating Effectively',
#        'custom_attributes': [],
#        'created_at': '2025-08-26T13:18:12Z',
#        'updated_at': '2025-08-26T14:24:55Z'},
#       'relationships': {}}]}}},
#  1)

# %%
# fetch control design data from walkthroughs *************************************
## data structure: {project_id: objective_id: control_id: [walkthroughs]}
### a control can have one or more testing data depending on the testing rounds
project_objectives_controls_walkthroughs = {}
for project in project_objectives_controls:
    project_id = project
    project_objectives_controls_walkthroughs[project_id] = {}   # dict to hold object-risk data for each project
    for objective in project_objectives_controls[project_id]:
        objective_id = objective
        project_objectives_controls_walkthroughs[project_id][objective_id]={}
        for control in project_objectives_controls[project_id][objective_id]:
            control_id = control['id']
            params = {'filter[project.id]':project_id, 'filter[control.id]':control_id} # filter for project and specified control
            BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/walkthroughs'
            walkthrough = fetch_data(BASE_URL, params=params)
            project_objectives_controls_walkthroughs[project_id][objective_id][control_id] = walkthrough
project_objectives_controls_walkthroughs, len(project_objectives_controls_walkthroughs)
# Out:
# ({'492704': {'1896423': {'14421648': [{'id': '10357901',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': '<p>Inadequate design \xa0</p>',
#        'control_design': False,
#        'created_at': '2025-08-26T13:18:09Z',
#        'updated_at': '2025-08-26T13:25:33Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421649': [{'id': '10357902',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': None,
#        'created_at': '2025-08-26T13:18:10Z',
#        'updated_at': '2025-08-26T13:18:10Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421650': [{'id': '10357903',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': None,
#        'created_at': '2025-08-26T13:18:10Z',
#        'updated_at': '2025-08-26T13:18:10Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421651': [{'id': '10357904',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': True,
#        'created_at': '2025-08-26T13:18:11Z',
#        'updated_at': '2025-08-26T13:26:59Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421652': [{'id': '10357905',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': True,
#        'created_at': '2025-08-26T13:18:11Z',
#        'updated_at': '2025-08-26T13:27:17Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421653': [{'id': '10357906',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': False,
#        'created_at': '2025-08-26T13:18:12Z',
#        'updated_at': '2025-08-26T13:27:32Z',
#        'custom_attributes': []},
#       'relationships': {}}],
#     '14421654': [{'id': '10357907',
#       'type': 'walkthroughs',
#       'attributes': {'walkthrough_results': None,
#        'control_design': None,
#        'created_at': '2025-08-26T13:18:12Z',
#        'updated_at': '2025-08-26T13:18:12Z',
#        'custom_attributes': []},
#       'relationships': {}}]}}},
#  1)

# %%
# fetch issues/findings data *************************************************
## targeted filters for projects, objectives, control, control test, risk

params = {'filter[project.id]':id}

BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/issues'
issues = fetch_data(BASE_URL, params=params)

issues, len(issues)
# Out:
# ([{'id': '1101239',
#    'type': 'issues',
#    'attributes': {'title': 'Lack of user manual or reference documents for some critical equipment ',
#     'description': '<p>Lack of user manuals or reference documents for some critical assets which provide guidance into their preventive maintenance. Examples of such equipment include:</p><p>Windward system for Impact repot mapping</p><p>This was mainly due to oversight.\xa0</p>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T13:41:18Z',
#     'updated_at': '2025-08-28T12:04:00Z',
#     'position': 1,
#     'owner': 'Manager Support',
#     'recommendation': '<p>Technicians/ Support should keep user manuals and or reference documents in the absence of the manual (such as international standards) for equipment after installation for reference when developing and implementing PMP.\xa0</p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T13:36:12Z',
#     'reference': '1',
#     'reference_prefix': '01-01',
#     'risk': '<p>Not referencing preventive maintenance to user/factory manual may compromise the overall assets integrity.\xa0</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': 'Awaiting Management Response',
#     'remediation_plan': '<p>The missing manuals/ reference documents are to be sourced and used in coming up with job cards for PM then shared with all depot technicians and depot supervisors\xa0</p>',
#     'remediation_date': '2023-11-30',
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['Nairobi'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101262',
#    'type': 'issues',
#    'attributes': {'title': 'Absence of job cards for some critical assets ',
#     'description': '<div class="OutlineElement Ltr SCXW267445657 BCX8" style=\'background-color:rgb(255, 255, 255);clear:both;color:rgb(0, 0, 0);cursor:text;direction:ltr;font-family:"Segoe UI", "Segoe UI Web", Arial, Verdana, sans-serif;font-size:12px;font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;overflow:visible;padding:0px;text-align:start;text-indent:0px;white-space:normal;\'><p class="Paragraph SCXW267445657 BCX8" style="background-color:transparent;color:windowtext;font-style:normal;font-weight:normal;margin:0px 0px 10.6667px;padding:0px;text-align:justify;text-indent:0px;vertical-align:baseline;"><span style=\'font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW267445657 BCX8 NormalTextRun" style="line-height:17.2667px;margin:0px;padding:0px;">Job cards for implementing support of some critical assets are yet to be developed. This is due to the maturity level of Preventive Maintenance management system as this process has just been initiated. Examples include:</span><span class="EOP SCXW267445657 BCX8" style="line-height:17.2667px;margin:0px;padding:0px;">\xa0</span></span></p></div><div class="OutlineElement Ltr SCXW267445657 BCX8" style=\'background-color:rgb(255, 255, 255);clear:both;color:rgb(0, 0, 0);cursor:text;direction:ltr;font-family:"Segoe UI", "Segoe UI Web", Arial, Verdana, sans-serif;font-size:12px;font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;overflow:visible;padding:0px;text-align:start;text-indent:0px;white-space:normal;\'><p class="Paragraph SCXW267445657 BCX8" style="background-color:transparent;color:windowtext;font-style:normal;font-weight:normal;margin:0px 0px 10.6667px;padding:0px;text-align:justify;text-indent:0px;vertical-align:baseline;"><span style=\'font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW267445657 BCX8 NormalTextRun" style="line-height:17.2667px;margin:0px;padding:0px;">Foam tank &amp; operating valves; Pressure Vacuum vents<strong>; </strong>Thermal relief valves<strong>; </strong>Offloading metering system<strong>; </strong>Tank valves (inlet, outlet, drain) and Water tanks.</span><span class="EOP SCXW267445657 BCX8" style="line-height:17.2667px;margin:0px;padding:0px;">\xa0</span></span></p></div>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:20:05Z',
#     'updated_at': '2025-08-26T14:20:05Z',
#     'position': 2,
#     'owner': 'Manager',
#     'recommendation': '<p><span style=\'background-color:rgb(255,255,255);color:rgb(0,0,0);font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW111830707 BCX8 NormalTextRun" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">Introduction of condition monitoring checklists for some of the equipment by bundling related equipment and accessories in one checklist or job card for example checklist for water/foam fire suppression system and accessories\xa0</span><span class="EOP SCXW111830707 BCX8" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">\xa0</span></span></p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:18:25Z',
#     'reference': '2',
#     'reference_prefix': '01-02',
#     'risk': '<p><span style=\'background-color:rgb(255,255,255);color:rgb(0,0,0);font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW128548630 BCX8 NormalTextRun" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">This may affect effective implementation of PMP and eventually affecting the overall equipment integrity</span><span class="EOP SCXW128548630 BCX8" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">\xa0</span></span></p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['All Offices'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101266',
#    'type': 'issues',
#    'attributes': {'title': 'Missing job cards for preventive maintenance ',
#     'description': '<p><span style=\'background-color:rgb(255,255,255);color:rgb(0,0,0);font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:13.3333px;\'><span class="NormalTextRun SCXW70202277 BCX8" style="font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">Missing job cards for preventive maintenance which may be due to poor filing and non-adherence to the PMP which indicates lower adherence rate than the 100% targe</span></span></p>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:22:13Z',
#     'updated_at': '2025-08-26T14:22:13Z',
#     'position': 3,
#     'owner': 'Manager IT',
#     'recommendation': '<div class="ListContainerWrapper SCXW235774513 BCX8" style=\'background-color:rgb(255, 255, 255);color:rgb(0, 0, 0);font-family:"Segoe UI", "Segoe UI Web", Arial, Verdana, sans-serif;font-size:12px;font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;padding:0px;text-align:start;text-indent:0px;white-space:normal;\'><ol style="list-style-type:lower-latin;"><li><p class="Paragraph SCXW235774513 BCX8" style="background-color:transparent;color:windowtext;font-style:normal;font-weight:normal;margin:0px;padding:0px;text-align:justify;text-indent:0px;vertical-align:baseline;"><span style=\'font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW235774513 BCX8 NormalTextRun" style="line-height:17.2667px;margin:0px;padding:0px;">Improvement on the filing</span><span class="EOP SCXW235774513 BCX8" style="line-height:17.2667px;margin:0px;padding:0px;">\xa0</span></span></p></li></ol></div><div class="ListContainerWrapper SCXW235774513 BCX8" style=\'background-color:rgb(255, 255, 255);color:rgb(0, 0, 0);font-family:"Segoe UI", "Segoe UI Web", Arial, Verdana, sans-serif;font-size:12px;font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;padding:0px;text-align:start;text-indent:0px;white-space:normal;\'><ol style="list-style-type:lower-latin;"><li><p class="Paragraph SCXW235774513 BCX8" style="background-color:transparent;color:windowtext;font-style:normal;font-weight:normal;margin:0px;padding:0px;text-align:justify;text-indent:0px;vertical-align:baseline;"><span style=\'font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW235774513 BCX8 NormalTextRun" style="line-height:17.2667px;margin:0px;padding:0px;">Ensuring 100% adherence to PMP</span><span class="EOP SCXW235774513 BCX8" style="line-height:17.2667px;margin:0px;padding:0px;">\xa0</span></span></p></li></ol></div><div class="ListContainerWrapper SCXW235774513 BCX8" style=\'background-color:rgb(255, 255, 255);color:rgb(0, 0, 0);font-family:"Segoe UI", "Segoe UI Web", Arial, Verdana, sans-serif;font-size:12px;font-style:normal;font-weight:400;letter-spacing:normal;margin:0px;padding:0px;text-align:start;text-indent:0px;white-space:normal;\'><ol style="list-style-type:lower-latin;"><li><p class="Paragraph SCXW235774513 BCX8" style="background-color:transparent;color:windowtext;font-style:normal;font-weight:normal;margin:0px;padding:0px;text-align:justify;text-indent:0px;vertical-align:baseline;"><span style=\'font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW235774513 BCX8 NormalTextRun" style="line-height:17.2667px;margin:0px;padding:0px;">Monthly reports on maintenance from DTs to TSM and DMs</span><span class="EOP SCXW235774513 BCX8" style="line-height:17.2667px;margin:0px;padding:0px;">\xa0</span></span></p></li></ol></div>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:20:43Z',
#     'reference': '3',
#     'reference_prefix': '01-03',
#     'risk': '<p><span style=\'background-color:rgb(255,255,255);color:rgb(0,0,0);font-family:"Century Gothic", "Century Gothic_EmbeddedFont", "Century Gothic_MSFontService", sans-serif;font-size:10pt;\'><span class="TextRun SCXW181812156 BCX8 NormalTextRun" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">Non-adherence to PMP may affect the overall equipment integrity</span><span class="EOP SCXW181812156 BCX8" style="font-style:normal;font-weight:400;letter-spacing:normal;line-height:17.2667px;margin:0px;padding:0px;text-align:justify;text-indent:0px;white-space:normal;">\xa0</span></span></p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['All Sites'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101270',
#    'type': 'issues',
#    'attributes': {'title': 'Un-updated job cards and PMP ',
#     'description': '<p>Mismatch between job cards and PMP in terms of frequency of preventive maintenance, for example fuel line strainer job card indicates a 2-weekly frequency while all the PMPs for all the depots show a monthly frequency for the same. This is mainly due to oversight,\xa0</p>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:24:24Z',
#     'updated_at': '2025-08-26T14:24:25Z',
#     'position': 4,
#     'owner': 'IT manager',
#     'recommendation': '<p>Review of the existing job cards with reference to the PMPs so that all are aligned in terms of frequency.</p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:22:42Z',
#     'reference': '4',
#     'reference_prefix': '01-04',
#     'risk': '<p>Different PMP schedules for the same equipment may affect the overall equipment integrity and optimal utilisation of resources</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['All Site'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101271',
#    'type': 'issues',
#    'attributes': {'title': 'Poor Structural condition on Foam tank and Diesel Cooling ring ',
#     'description': '<p>oor structural condition for some critical equipment due to non-adherence to preventive maintenance i.e., aggressive rust development on the foam tank and diesel tank cooling ring\xa0</p>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:28:43Z',
#     'updated_at': '2025-08-26T14:28:43Z',
#     'position': 5,
#     'owner': 'Manager IT',
#     'recommendation': '<ol style="list-style-type:upper-roman;">\n<li>Corrective maintenance should be done on the affected equipment (rust treatment and repainting)</li>\n<li>Repositioning of the sprinkler nozzle to reduce water dripping to curb future rust development\xa0</li>\n</ol>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:24:59Z',
#     'reference': '5',
#     'reference_prefix': '01-05',
#     'risk': '<p>Ineffective response to an emergency because the integrity of the equipment is compromised\xa0</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['All Site'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101272',
#    'type': 'issues',
#    'attributes': {'title': 'Absence of test plan for satellites depots ',
#     'description': "<p>Satellite depots' equipment not on PMP (Mchinji, Chipoka and Condrill sites-Kanengo &amp; Kapichira) due oversight\xa0</p>",
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:30:23Z',
#     'updated_at': '2025-08-26T14:30:23Z',
#     'position': 6,
#     'owner': 'Manager IT',
#     'recommendation': '<p>A PMP for these sites should be developed and adhered to.\xa0</p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:29:07Z',
#     'reference': '6',
#     'reference_prefix': '01-06',
#     'risk': '<p>No guarantee can be placed on the integrity of the \xa0</p><p>equipment in these sites\xa0</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['Johannessburg'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101273',
#    'type': 'issues',
#    'attributes': {'title': 'Failure to adhere to contractual terms (Mchinji Concession Agreement) ',
#     'description': '<p>Nonadherence to contractual obligations on performance and monitoring of equipment for Mchinji depot due to oversight. This include, regular inspections and performance reviews.\xa0</p>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:33:05Z',
#     'updated_at': '2025-08-26T14:33:05Z',
#     'position': 7,
#     'owner': 'IT Manager',
#     'recommendation': '<p>Enforcement of the contractual obligations to help in the equipment and asset management\xa0</p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:31:21Z',
#     'reference': '7',
#     'reference_prefix': '01-07',
#     'risk': '<p>This will affect the overall equipment integrity\xa0</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['Nairobi'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}},
#   {'id': '1101279',
#    'type': 'issues',
#    'attributes': {'title': 'No preventive maintenance or condition monitoring of some equipment ',
#     'description': '<p>No preventive maintenance or condition monitoring of equipment that are not are not included in the PMP but are available in the equipment registers such as:</p><p>submersible water tank</p><p>submersible water pump</p><ol style="list-style-type:lower-latin;">\n<li>Water tank</li>\n<li>Lawn mower</li>\n<li>Breathalyzer</li>\n<li>Metal detector</li>\n<li>Thermoprobe</li>\n<li>Transfer pump\xa0</li>\n</ol>',
#     'creator_name': 'Dinah Maina',
#     'created_at': '2025-08-26T14:35:44Z',
#     'updated_at': '2025-08-26T14:35:44Z',
#     'position': 8,
#     'owner': 'Manager IT',
#     'recommendation': '<p>Developing condition monitoring checklist for related equipment to ensure their integrity is not compromised.\xa0</p>',
#     'deficiency_type': 'Finding',
#     'severity': None,
#     'published': True,
#     'identified_at': '2025-08-26T14:31:21Z',
#     'reference': '8',
#     'reference_prefix': '01-07',
#     'risk': '<p>This will affect the overall equipment integrity\xa0</p>',
#     'scope': None,
#     'escalation': None,
#     'cause': '',
#     'effect': '',
#     'cost_impact': None,
#     'executive_summary': None,
#     'executive_owner': None,
#     'project_owner': None,
#     'closed': False,
#     'remediation_status': None,
#     'remediation_plan': None,
#     'remediation_date': None,
#     'actual_remediation_date': None,
#     'retest_deadline_date': None,
#     'actual_retest_date': None,
#     'retesting_results_overview': None,
#     'custom_attributes': [{'id': '152165',
#       'term': 'Site',
#       'value': ['All Sites'],
#       'required': False,
#       'default_values': []}]},
#    'relationships': {'project': {'data': {'id': '492704', 'type': 'projects'}},
#     'owner_user': {'data': None},
#     'executive_owner_user': {'data': None},
#     'project_owner_user': {'data': None},
#     'creator_user': {'data': {'id': 'k774cbJfz5Rp9stNLg4C',
#       'type': 'users'}}}}],
#  8)

# %%
BASE_URL = f'https://apis-us.diligentoneplatform.com/v1/orgs/{org_id}/frameworks'
frameworks = fetch_data(BASE_URL)
frameworks , len(frameworks)
# Out:
# ([{'id': '245399',
#    'type': 'frameworks',
#    'attributes': {'name': 'Anti Bribery and Corruption',
#     'created_at': '2023-08-18T12:28:50Z',
#     'updated_at': '2024-06-03T08:06:20Z',
#     'description': '',
#     'background': '<p>Anti-bribery and anti-corruption risks are not well mitigated by standard (i.e. reporting focused) financial controls. The impact of non-compliance to anti-bribery and anti-corruption legislation is potential investigation by authorities leading to fines up to billions.</p>\r\n\r\n<p>Organizations with operations in the United States are subject to the Foreign Corrupt Practices Act, and organizations connected with the United Kingdom are subject to the U.K. Bribery Act.</p>\r\n\r\n<p>The <strong>Foreign Corrupt Practices Act</strong> (FCPA) of 1977 is a US Federal Law primarily intended to prohibit payments of bribes to foreign officials and political figures (also know as the Anti-Bribery Provision). The second provision requires that companies maintain transparency requirements for business accounting as outlined by the Securities Exchange Act of 1934 (also know as the Accounting Provision).</p>\r\n\r\n<p>The<strong> Bribery Act</strong> of 2010 is a UK law that creates four distinct criminal offences of:</p>\r\n\r\n<ul>\r\n\t<li>Bribing another &ndash; i.e., the offering, promising or giving of an advantage to another person</li>\r\n\t<li>Being bribed &ndash; i.e., the requesting, agreeing to receive or accepting of an advantage from another person</li>\r\n\t<li>Bribing a foreign official</li>\r\n\t<li>Failing to prevent bribery (for commercial organisations)</li>\r\n</ul>\r\n',
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': '<p>This program is intended to provide you with insight on preventing and detecting anti-bribery/corruption risk, and should not be construed as legal advice on the part of ACL.</p>\r\n\r\n<p>Anti-bribery and anti-corruption legislation is complex. You are cautioned to obtain independent, qualified legal and accounting advice regarding the regulations that affect your organization.</p>\r\n',
#     'scope': '<p>This program will provide guidance on how to implement preventative and detective controls in your organization to mitigate the process-level risks related to anti-bribery and anti-corruption.</p>\r\n\r\n<p>We will include all key business processes and general governance within the project scope, specifically:</p>\r\n\r\n<ul>\r\n\t<li>Governance &amp; Business Partners</li>\r\n\t<li>General Ledger</li>\r\n\t<li>Vendor Management</li>\r\n\t<li>Purchase to Payment</li>\r\n\t<li>Order to Cash</li>\r\n\t<li>Payroll</li>\r\n\t<li>Travel and Entertainment</li>\r\n</ul>\r\n',
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'Increased investments in efficiencies in the value chain'},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}}},
#   {'id': '245403',
#    'type': 'frameworks',
#    'attributes': {'name': 'Order to Cash',
#     'created_at': '2023-08-18T12:32:56Z',
#     'updated_at': '2024-06-03T07:57:51Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '63472',
#       'type': 'project_types'}}}},
#   {'id': '245405',
#    'type': 'frameworks',
#    'attributes': {'name': 'Sales commission',
#     'created_at': '2023-08-18T12:35:55Z',
#     'updated_at': '2023-08-18T12:44:39Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'Dummy Framework'},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}}},
#   {'id': '245407',
#    'type': 'frameworks',
#    'attributes': {'name': 'IT General Controls',
#     'created_at': '2023-08-18T12:40:20Z',
#     'updated_at': '2024-06-03T07:57:26Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '64280',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '64281',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '63470',
#       'type': 'project_types'}}}},
#   {'id': '248185',
#    'type': 'frameworks',
#    'attributes': {'name': 'Secure Controls Framework 2020.4',
#     'created_at': '2023-09-19T08:26:27Z',
#     'updated_at': '2023-09-19T08:26:27Z',
#     'description': '',
#     'background': '',
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': '',
#     'scope': '',
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '313080',
#       'type': 'project_types'}}}},
#   {'id': '250643',
#    'type': 'frameworks',
#    'attributes': {'name': 'Accounts payble',
#     'created_at': '2023-10-18T08:14:36Z',
#     'updated_at': '2024-06-03T08:06:14Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '62965',
#       'term': 'Scope exclusion',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '62966',
#       'term': 'Audit approach',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '62972',
#       'term': 'Please select status of project',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'Diversification,horizontal integration and consolidation'},
#    'relationships': {'project_type': {'data': {'id': '302391',
#       'type': 'project_types'}}}},
#   {'id': '251406',
#    'type': 'frameworks',
#    'attributes': {'name': 'Training Library',
#     'created_at': '2023-10-26T09:37:10Z',
#     'updated_at': '2023-10-26T09:37:10Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '308376',
#       'type': 'project_types'}}}},
#   {'id': '254871',
#    'type': 'frameworks',
#    'attributes': {'name': 'Leave Management',
#     'created_at': '2023-11-30T08:11:18Z',
#     'updated_at': '2023-11-30T08:11:18Z',
#     'description': 'ABC',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '306348',
#       'type': 'project_types'}}}},
#   {'id': '261793',
#    'type': 'frameworks',
#    'attributes': {'name': 'Sygnia',
#     'created_at': '2024-01-22T12:25:50Z',
#     'updated_at': '2024-01-22T12:25:50Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '58137',
#       'term': 'What is your name',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '60668',
#       'term': 'Persons',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '292899',
#       'type': 'project_types'}}}},
#   {'id': '282095',
#    'type': 'frameworks',
#    'attributes': {'name': 'Training',
#     'created_at': '2024-01-24T08:33:13Z',
#     'updated_at': '2024-01-24T08:34:46Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '306625',
#       'type': 'project_types'}}}},
#   {'id': '287302',
#    'type': 'frameworks',
#    'attributes': {'name': 'ICT - CRMP',
#     'created_at': '2024-02-21T07:40:40Z',
#     'updated_at': '2024-02-21T07:40:40Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '319988',
#       'type': 'project_types'}}}},
#   {'id': '287876',
#    'type': 'frameworks',
#    'attributes': {'name': 'Chief Financial Officer',
#     'created_at': '2024-02-26T12:52:43Z',
#     'updated_at': '2024-06-03T08:06:28Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': 'Reorganisation of business models and unlocking value synergies'},
#    'relationships': {'project_type': {'data': {'id': '324925',
#       'type': 'project_types'}}}},
#   {'id': '289971',
#    'type': 'frameworks',
#    'attributes': {'name': 'Corporate Services Department',
#     'created_at': '2024-03-05T08:13:43Z',
#     'updated_at': '2024-06-03T08:06:34Z',
#     'description': 'Human Capital\r\nICT \r\nMarketing and Communication ',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': 'Externalisation'},
#    'relationships': {'project_type': {'data': {'id': '306348',
#       'type': 'project_types'}}}},
#   {'id': '297190',
#    'type': 'frameworks',
#    'attributes': {'name': 'Hemita vodacom',
#     'created_at': '2024-04-16T10:04:45Z',
#     'updated_at': '2024-04-16T10:04:45Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '38407',
#       'term': 'Executive Summary ',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '186443',
#       'type': 'project_types'}}}},
#   {'id': '297233',
#    'type': 'frameworks',
#    'attributes': {'name': 'Audit administration',
#     'created_at': '2024-04-16T13:07:22Z',
#     'updated_at': '2024-06-03T08:06:25Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': 'Internal integration of the customer'},
#    'relationships': {'project_type': {'data': {'id': '251247',
#       'type': 'project_types'}}}},
#   {'id': '300826',
#    'type': 'frameworks',
#    'attributes': {'name': 'test',
#     'created_at': '2024-05-16T12:18:38Z',
#     'updated_at': '2024-05-16T12:18:38Z',
#     'description': 'test link',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '38407',
#       'term': 'Executive Summary ',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '186443',
#       'type': 'project_types'}}}},
#   {'id': '312744',
#    'type': 'frameworks',
#    'attributes': {'name': 'Alex Forbes Test',
#     'created_at': '2024-08-28T13:11:45Z',
#     'updated_at': '2024-08-29T07:25:43Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '89607',
#       'term': 'Responsible Person(s):',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '89608',
#       'term': 'Initial Report Rating',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '89609',
#       'term': 'Report Distribution',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '89610',
#       'term': 'Executive Summary Background',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '89611',
#       'term': 'Legal Entity',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '89630',
#       'term': 'Platform',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '347986',
#       'type': 'project_types'}}}},
#   {'id': '313221',
#    'type': 'frameworks',
#    'attributes': {'name': 'Senwes testing',
#     'created_at': '2024-09-04T06:55:32Z',
#     'updated_at': '2024-09-04T06:55:32Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '62965',
#       'term': 'Scope exclusion',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '62966',
#       'term': 'Audit approach',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '62972',
#       'term': 'Please select status of project',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '302391',
#       'type': 'project_types'}}}},
#   {'id': '344586',
#    'type': 'frameworks',
#    'attributes': {'name': 'ZS Test 2025',
#     'created_at': '2025-01-08T13:02:08Z',
#     'updated_at': '2025-01-08T13:02:08Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '362042',
#       'type': 'project_types'}}}},
#   {'id': '356009',
#    'type': 'frameworks',
#    'attributes': {'name': 'Training ULM 27012025',
#     'created_at': '2025-01-27T09:23:01Z',
#     'updated_at': '2025-01-27T10:14:48Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '60978',
#       'term': 'CA1',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '60979',
#       'term': 'CA2',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '60980',
#       'term': 'CA3',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '60981',
#       'term': 'CA4',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '60982',
#       'term': 'CA5',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '300736',
#       'type': 'project_types'}}}},
#   {'id': '357543',
#    'type': 'frameworks',
#    'attributes': {'name': 'ZS23',
#     'created_at': '2025-01-30T08:00:18Z',
#     'updated_at': '2025-02-04T09:10:09Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '75096',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '75097',
#       'term': 'ERMF',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '326888',
#       'type': 'project_types'}}}},
#   {'id': '373833',
#    'type': 'frameworks',
#    'attributes': {'name': '007 framework',
#     'created_at': '2025-02-25T06:44:03Z',
#     'updated_at': '2025-03-24T13:01:14Z',
#     'description': 'DO NOT TOUCH',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '366804',
#       'type': 'project_types'}}}},
#   {'id': '390447',
#    'type': 'frameworks',
#    'attributes': {'name': 'Wambui Test Framework',
#     'created_at': '2025-03-18T08:18:11Z',
#     'updated_at': '2025-03-18T08:18:11Z',
#     'description': 'This is a test framework for Demo purposes',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '190373',
#       'type': 'project_types'}}}},
#   {'id': '390452',
#    'type': 'frameworks',
#    'attributes': {'name': 'Collective Investment Schemes Control Act, No. 45 of 2002',
#     'created_at': '2025-03-18T09:34:21Z',
#     'updated_at': '2025-06-05T12:06:16Z',
#     'description': 'Collective Investment Schemes Control Act, No. 45 of 2002',
#     'background': None,
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': 'nothing'},
#    'relationships': {'project_type': {'data': {'id': '339713',
#       'type': 'project_types'}}}},
#   {'id': '441806',
#    'type': 'frameworks',
#    'attributes': {'name': 'Hemi and jason',
#     'created_at': '2025-05-26T13:10:57Z',
#     'updated_at': '2025-05-26T13:10:57Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '398409',
#       'type': 'project_types'}}}},
#   {'id': '443983',
#    'type': 'frameworks',
#    'attributes': {'name': 'Compliance to frameworks - Jason Test',
#     'created_at': '2025-05-30T08:17:51Z',
#     'updated_at': '2025-05-30T08:17:51Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '399300',
#       'type': 'project_types'}}}},
#   {'id': '444015',
#    'type': 'frameworks',
#    'attributes': {'name': 'Regulation Library - Jason Test',
#     'created_at': '2025-05-30T08:50:09Z',
#     'updated_at': '2025-05-30T09:15:17Z',
#     'description': 'This frameworks consists of regulations that are migrated from compliance maps',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '399300',
#       'type': 'project_types'}}}},
#   {'id': '451676',
#    'type': 'frameworks',
#    'attributes': {'name': 'HINT-Underwriting',
#     'created_at': '2025-06-09T13:21:53Z',
#     'updated_at': '2025-06-09T13:21:53Z',
#     'description': 'This contain the risk register for underwriting',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '401180',
#       'type': 'project_types'}}}},
#   {'id': '473955',
#    'type': 'frameworks',
#    'attributes': {'name': 'Income Tax Act, No. 58 of 1962',
#     'created_at': '2025-07-11T13:28:27Z',
#     'updated_at': '2025-07-11T13:28:27Z',
#     'description': 'Income Tax Act, No. 58 of 1962',
#     'background': None,
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '109372',
#       'term': 'LN Act ID',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'CM2F'},
#    'relationships': {'project_type': {'data': {'id': '373644',
#       'type': 'project_types'}}}},
#   {'id': '476326',
#    'type': 'frameworks',
#    'attributes': {'name': 'Income Tax Act, No. 58 of 1962',
#     'created_at': '2025-07-14T12:55:39Z',
#     'updated_at': '2025-07-14T12:55:39Z',
#     'description': 'Income Tax Act, No. 58 of 1962',
#     'background': None,
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '143321',
#       'term': 'LN Act ID',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'CM2F'},
#    'relationships': {'project_type': {'data': {'id': '410222',
#       'type': 'project_types'}}}},
#   {'id': '478109',
#    'type': 'frameworks',
#    'attributes': {'name': 'Cybercrimes Act, No. 19 of 2020',
#     'created_at': '2025-07-17T08:44:26Z',
#     'updated_at': '2025-07-17T08:44:26Z',
#     'description': 'Cybercrimes Act, No. 19 of 2020',
#     'background': None,
#     'position': 0,
#     'risk_assurance': False,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '109372',
#       'term': 'LN Act ID',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': 'CM2F'},
#    'relationships': {'project_type': {'data': {'id': '373644',
#       'type': 'project_types'}}}},
#   {'id': '485299',
#    'type': 'frameworks',
#    'attributes': {'name': 'FMB',
#     'created_at': '2025-08-01T07:26:22Z',
#     'updated_at': '2025-08-01T07:26:22Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '409575',
#       'type': 'project_types'}}}},
#   {'id': '489126',
#    'type': 'frameworks',
#    'attributes': {'name': "Thato's Risk Training",
#     'created_at': '2025-08-14T06:22:04Z',
#     'updated_at': '2025-08-14T06:22:04Z',
#     'description': 'R in ARC',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '190373',
#       'type': 'project_types'}}}},
#   {'id': '492691',
#    'type': 'frameworks',
#    'attributes': {'name': 'Custom Reporting Test-Gabriel',
#     'created_at': '2025-08-26T09:08:13Z',
#     'updated_at': '2025-08-26T09:08:13Z',
#     'description': '',
#     'background': None,
#     'position': 0,
#     'risk_assurance': True,
#     'purpose': None,
#     'scope': None,
#     'custom_attributes': [{'id': '151043',
#       'term': 'Scope',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '152124',
#       'term': 'Department',
#       'value': None,
#       'required': False,
#       'default_values': []},
#      {'id': '152132',
#       'term': 'Report Date',
#       'value': None,
#       'required': False,
#       'default_values': []}],
#     'folder_name': ''},
#    'relationships': {'project_type': {'data': {'id': '419957',
#       'type': 'project_types'}}}}],
#  34)
